# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy
# %matplotlib inline

# %%
airbnb = pd.read_csv('/Users/salilketkar/thinkful/airbnb challenge/listings2.csv')
airbnbMod = airbnb.iloc[:,9:]
airbnbMod.head()
# Out:
#    host_total_listings_count  accommodates  bathrooms  bedrooms  beds  \
# 0                        1.0             4        1.0       1.0   2.0
# 1                       51.0             6        1.0       2.0   4.0
# 2                       51.0             8        2.0       3.0   6.0
# 3                        2.0             3        1.0       1.0   1.0
# 4                        2.0             2        1.0       1.0   1.0
#
#    square_feet     price weekly_price monthly_price security_deposit  \
# 0          NaN  $100.00           NaN           NaN         $120.00
# 1         75.0  $130.00           NaN           NaN         $150.00
# 2          NaN  $130.00           NaN           NaN         $150.00
# 3          NaN   $32.00      $185.00       $580.00               NaN
# 4        108.0   $33.00           NaN           NaN         $100.00
#
#          ...         requires_license      license jurisdiction_names  \
# ...

# %% [markdown]
# ### Data Cleaning

# %%
airbnbMod['price'] = airbnbMod['price'].apply(lambda x: str(x).replace('$',''))
airbnbMod['price'] = airbnbMod['price'].apply(lambda x: str(x).replace(',',''))
airbnbMod['price'] = airbnbMod['price'].apply(lambda x: str(x).replace('.',''))
airbnbMod['price'] = pd.to_numeric(airbnbMod['price'])


airbnbMod1 = airbnbMod.select_dtypes(include=['number'])
airbnbMod1.drop(['minimum_nights','maximum_nights','square_feet','jurisdiction_names','availability_30','availability_60','availability_90','availability_365'],axis=1,inplace=True)
airbnbMod1.dropna(inplace=True)


pd.set_option('display.max_columns',100)
airbnbMod1.head()
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py:3694: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
#    host_total_listings_count  accommodates  bathrooms  bedrooms  beds  price  \
# 0                        1.0             4        1.0       1.0   2.0  10000
# 1                       51.0             6        1.0       2.0   4.0  13000
# 2                       51.0             8        2.0       3.0   6.0  13000
# ...

# %%
airbnbData = airbnbMod1.drop('price',axis=1)
airbnbTarget = airbnbMod1.price

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(airbnbData, airbnbTarget, test_size=0.3)

# %%
from sklearn import tree

import timeit

start = timeit.default_timer()

decision_tree = tree.DecisionTreeRegressor(
max_features='auto',
min_samples_split=30
)

decision_tree.fit(X_train, y_train)
stop = timeit.default_timer()

print('Time: ', stop - start) 



print('Accuracy for train data:',decision_tree.score(X_train,y_train))
print('Accuracy for test data:',decision_tree.score(X_test,y_test))
# Out:
# Time:  0.051684691017726436
# Accuracy for train data: 0.41481934332960657
# Accuracy for test data: 0.46376087673004984

# %%
from sklearn.ensemble import RandomForestRegressor
import timeit

start = timeit.default_timer()

rf = RandomForestRegressor()
rf.fit(X_train,y_train)

stop = timeit.default_timer()

print('Time: ', stop - start) 


print('Accuracy for train data:',rf.score(X_train,y_train))
print('Accuracy for test data:',rf.score(X_test, y_test))
# Out:
# Time:  0.4328557780245319
# Accuracy for train data: 0.8469785657087353
# Accuracy for test data: 0.5258291056712602

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(decision_tree, X_test, y_test, cv=10)
# Out:
# array([0.45175349, 0.12484786, 0.30481929, 0.24646073, 0.30028649,
#        0.26209283, 0.41537023, 0.48525538, 0.47589069, 0.25969866])

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(rf, X_test, y_test, cv=10)
# Out:
# array([0.51522582, 0.57582363, 0.53673787, 0.3546378 , 0.49819887,
#        0.61895064, 0.49748313, 0.52287426, 0.44699015, 0.17602806])
